# %%
a = 20
b = 3.14
c = "Host"
d = True
print("type a:", type (a))
print("type b:", type (b))
print("type c:", type (c))
print("type d:", type (d))
# Out:
# type a: <class 'int'>
# type b: <class 'float'>
# type c: <class 'str'>
# type d: <class 'bool'>

# %%
# Different variables
a = 100
b = 45.67
c = "Python"
d = True
e = [1, 2, 3]
f = (10, 20)

# Displaying data types
print("a =", a, "Type:", type(a))
print("b =", b, "Type:", type(b))
print("c =", c, "Type:", type(c))
print("d =", d, "Type:", type(d))
print("e =", e, "Type:", type(e))
print("f =", f, "Type:", type(f))
# Out:
# a = 100 Type: <class 'int'>
# b = 45.67 Type: <class 'float'>
# c = Python Type: <class 'str'>
# d = True Type: <class 'bool'>
# e = [1, 2, 3] Type: <class 'list'>
# f = (10, 20) Type: <class 'tuple'>

# %%
student_name = "Tanvitha"
roll_number = 2520030385
age = 19
branch = "CSE"
cgpa = 8.75
is_hosteller = True
print("Student Name:", student_name, "| Data Type:", type(student_name))
print("Roll Number:", roll_number, "| Data Type:", type(roll_number))
print("Age:", age, "| Data Type:", type(age))
print("Branch:", branch, "| Data Type:", type(branch))
print("CGPA:", cgpa, "| Data Type:", type(cgpa))
print("Is Hosteller:", is_hosteller, "| Data Type:", type(is_hosteller))
# Out:
# Student Name: Tanvitha | Data Type: <class 'str'>
# Roll Number: 2520030385 | Data Type: <class 'int'>
# Age: 19 | Data Type: <class 'int'>
# Branch: CSE | Data Type: <class 'str'>
# CGPA: 8.75 | Data Type: <class 'float'>
# Is Hosteller: True | Data Type: <class 'bool'>

# %%
a = 2
b = 6
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a ** 6 =", a ** 6)
# Out:
# a + b = 8
# a - b = -4
# a * b = 12
# a / b = 0.3333333333333333
# a ** 6 = 64

# %%
cgpa = 8.4
print("cgpa == 8.4", cgpa == 8.4)
print("cgpa > 8.4", cgpa > 8.4)
print("cgpa < 8.4", cgpa < 8.4)
print("cgpa >= 8.4", cgpa >= 8.4)
print("cgpa <= 8.4", cgpa <= 8.4)
# Out:
# cgpa == 8.4 True
# cgpa > 8.4 False
# cgpa < 8.4 False
# cgpa >= 8.4 True
# cgpa <= 8.4 True

# %%
model_name = "Logistic Regression"
accuracy = 0.87345

print("Accuracy of " + model_name + " is " + str(accuracy))
print(f"Accuracy of {model_name} is {accuracy}")
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.873

# %%
features = ["CGPA", "AptitudeTestScore", "CodingTestScore", "MockInterviewScore"]
print(features)
print(features[0])
print(features[1])
print(features[-1])
print(len(features))
print(features[0:2])
features.append("Internships")
print(features)
# Out:
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore']
# CGPA
# AptitudeTestScore
# MockInterviewScore
# 4
# ['CGPA', 'AptitudeTestScore']
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore', 'Internships']

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet
models = {
"Ridge": Ridge(alpha=1.0),
 "Lasso": Lasso(alpha=0.01),
"ElasticNet": ElasticNet(alpha=0.01),

}
print(models)
print(models["Ridge"])

for name, model in models.items():
 print(f"Model name: {name} -> Object: {model}")
# Out:
# {'Ridge': Ridge(), 'Lasso': Lasso(alpha=0.01), 'ElasticNet': ElasticNet(alpha=0.01)}
# Ridge()
# Model name: Ridge -> Object: Ridge()
# Model name: Lasso -> Object: Lasso(alpha=0.01)
# Model name: ElasticNet -> Object: ElasticNet(alpha=0.01)
